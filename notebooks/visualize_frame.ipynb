# %%
import cv2
import matplotlib.pyplot as plt

from penalty_vision.processing.video_processor import VideoProcessor

video_path = "<path>"
kick_frame = "<value>"

with VideoProcessor(video_path) as video_processor:
    frames = video_processor.extract_all_frames_as_array()

frame_rgb = cv2.cvtColor(frames[kick_frame], cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(frame_rgb)
plt.axis('off')
plt.show()
# Out:
# 2025-10-17 15:56:17 | PenaltyVision | INFO | __init__:28 | Video: penalty_297.mp4 | Frame count: 76 | 1280x720 | 25.0fps | 3.0s
# 2025-10-17 15:56:17 | PenaltyVision | INFO | extract_all_frames:79 | Extracted 76 frames out from 76 total
# 2025-10-17 15:56:17 | PenaltyVision | INFO | release:91 | Released video: penalty_297.mp4
